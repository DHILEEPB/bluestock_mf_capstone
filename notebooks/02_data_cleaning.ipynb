# %% [markdown]
# # Mutual Fund Analytics — Stage 2: Data Cleaning & Standardisation
# ## Capstone Project | Day 2 | Data Integrity & Consistency
#
# **Author:** Senior Data Engineer
# **Purpose:** Clean and validate mutual fund data by handling missing values, standardizing date strings, capping outliers, and enforcing positive limits.

# %%
# Imports
import pandas as pd
import numpy as np
from pathlib import Path

PROJECT_ROOT = Path().resolve().parent
PROCESSED_DIR = PROJECT_ROOT / "data" / "processed"
print(f"Processed data path: {PROCESSED_DIR}")

# %% [markdown]
# ### Clean & Parse Date Column

# %%
if (PROCESSED_DIR / "nav_history_clean.csv").exists():
    df_nav = pd.read_csv(PROCESSED_DIR / "nav_history_clean.csv")
    print(f"Loaded {len(df_nav)} clean NAV observations.")
    print(df_nav.info())
else:
    print("Run etl_pipeline.py to populate clean data in processed/.")
